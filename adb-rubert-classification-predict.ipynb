# %%
# !pip install mlflow
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting mlflow
#   Downloading mlflow-1.21.0-py3-none-any.whl (16.9 MB)
#      |████

# %%
# Also autoinstruments tf.keras
import mlflow.tensorflow
mlflow.tensorflow.autolog()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2021/11/24 13:47:25 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of tensorflow. If you encounter errors during autologging, try upgrading / downgrading tensorflow to a supported version, or try upgrading MLflow.
# </div>

# %%
# !pip install --upgrade pip
# !pip install transformers==4.12.5
# !pip install simpletransformers==0.63.3
# !pip install tensorboardX==2.4
#!pip install torch==1.7.1+cu110
# !pip install tensorflow==2.6.2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting transformers==4.12.5
#   Downloading transformers-4.12.5-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 18.5 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 83.2 MB/s
#
# *** WARNING: skipped 3916051 bytes of output ***
#
# Collecting google-auth&lt;2,&gt;=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 83.3 MB/s
# Requirement already satisfied: werkzeug&gt;=0.11.15 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (2.0.2)
# Requirement already satisfied: requests&lt;3,&gt;=2.21.0 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib&lt;0.5,&gt;=0.4.1 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (0.4.6)
# Requirement already satisfied: setuptools&gt;=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (52.0.0)
# Requirement already satisfied: tensorboard-data-server&lt;0.7.0,&gt;=0.6.0 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit&gt;=1.6.0 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (1.8.0)
# Requirement already satisfied: markdown&gt;=2.6.8 in /databricks/python3/lib/python3.8/site-packages (from tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (3.3.6)
# Requirement already satisfied: rsa&lt;5,&gt;=3.1.4 in /databricks/python3/lib/python3.8/site-packages (from google-auth&lt;2,&gt;=1.6.3-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (4.8)
# Requirement already satisfied: cachetools&lt;5.0,&gt;=2.0.0 in /databricks/python3/lib/python3.8/site-packages (from google-auth&lt;2,&gt;=1.6.3-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (4.2.4)
# Requirement already satisfied: pyasn1-modules&gt;=0.2.1 in /databricks/python3/lib/python3.8/site-packages (from google-auth&lt;2,&gt;=1.6.3-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (0.2.8)
# Requirement already satisfied: requests-oauthlib&gt;=0.7.0 in /databricks/python3/lib/python3.8/site-packages (from google-auth-oauthlib&lt;0.5,&gt;=0.4.1-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (1.3.0)
# Requirement already satisfied: importlib-metadata&gt;=4.4 in /databricks/python3/lib/python3.8/site-packages (from markdown&gt;=2.6.8-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (4.8.2)
# Requirement already satisfied: zipp&gt;=0.5 in /databricks/python3/lib/python3.8/site-packages (from importlib-metadata&gt;=4.4-&gt;markdown&gt;=2.6.8-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (3.6.0)
# Requirement already satisfied: pyasn1&lt;0.5.0,&gt;=0.4.6 in /databricks/python3/lib/python3.8/site-packages (from pyasn1-modules&gt;=0.2.1-&gt;google-auth&lt;2,&gt;=1.6.3-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (0.4.8)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.21.0-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (2020.12.5)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.21.0-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (4.0.0)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.21.0-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&lt;3,&gt;=2.21.0-&gt;tensorboard&lt;2.7,&gt;=2.6.0-&gt;tensorflow==2.6.2) (2.10)
# Requirement already satisfied: oauthlib&gt;=3.0.0

# %%
# !pip install torch==1.7.1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Requirement already satisfied: torch==1.7.1 in /databricks/python3/lib/python3.8/site-packages (1.7.1)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.8/site-packages (from torch==1.7.1) (3.7.4.3)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.8/site-packages (from torch==1.7.1) (1.19.2)
# </div>

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score, accuracy_score
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import logging
logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>

# %%
model_test = ClassificationModel('bert','model', use_cuda = False) # использование CPU
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">404 Client Error: Not Found for url: https://huggingface.co/model/resolve/main/config.json
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# INFO:py4j.java_gateway:Received command c on object id p0
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">HTTPError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/transformers/configuration_utils.py</span> in <span class="ansi-cyan-fg">get_config_dict</span><span class="ansi-blue-fg">(cls, pretrained_model_name_or_path, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    549</span>             <span class="ansi-red-fg"># Load from URL or cache if already cached</span>
# <span class="ansi-green-fg">--&gt; 550</span><span class="ansi-red-fg">             resolved_config_file = cached_path(
# </span><span class="ansi-green-intense-fg ansi-bold">    551</span>                 config_file<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/transformers/file_utils.py</span> in <span class="ansi-cyan-fg">cached_path</span><span class="ansi-blue-fg">(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1490</span>         <span class="ansi-red-fg"># URL, so get it from the cache (downloading if necessary)</span>
# <span class="ansi-green-fg">-&gt; 1491</span><span class="ansi-red-fg">         output_path = get_from_cache(
# </span><span class="ansi-green-intense-fg ansi-bold">   1492</span>             url_or_filename<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/transformers/file_utils.py</span> in <span class="ansi-cyan-fg">get_from_cache</span><span class="ansi-blue-fg">(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1662</span>             r <span class="ansi-blue-fg">=</span> requests<span class="ansi-blue-fg">.</span>head<span class="ansi-blue-fg">(</span>url<span class="ansi-blue-fg">,</span> headers<span class="ansi-blue-fg">=</span>headers<span class="ansi-blue-fg">,</span> allow_redirects<span class="ansi-blue-fg">=</span><span class="ansi-green-fg">False</span><span class="ansi-blue-fg">,</span> proxies<span class="ansi-blue-fg">=</span>proxies<span class="ansi-blue-fg">,</span> timeout<span class="ansi-blue-fg">=</span>etag_timeout<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1663</span><span class="ansi-red-fg">             </span>r<span class="ansi-blue-fg">.</span>raise_for_status<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1664</span>             etag <span class="ansi-blue-fg">=</span> r<span class="ansi-blue-fg">.</span>headers<span class="ansi-blue-fg">.</span>get<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;X-Linked-Etag&#34;</span><span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">or</span> r<span class="ansi-blue-fg">.</span>headers<span class="ansi-blue-fg">.</span>get<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ETag&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/requests/models.py</span> in <span class="ansi-cyan-fg">raise_for_status</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">    942</span>         <span class="ansi-green-fg">if</span> http_error_msg<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 943</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">raise</span> HTTPError<span class="ansi-blue-fg">(</span>http_error_msg<span class="ansi-blue-fg">,</span> response<span class="ansi-blue-fg">=</span>self<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    944</span>
#
# <span class="ansi-red-fg">HTTPError</span>: 404 Client Error: Not Found for url: https://huggingface.co/model/resolve/main/config.json
#
# During handling of the above exception, another exception occurred:
#
# <span class="ansi-red-fg">OSError</span>                                   Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3181682341363318&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>model_test <span class="ansi-blue-fg">=</span> ClassificationModel<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;bert&#39;</span><span class="ansi-blue-fg">,</span><span class="ansi-blue-fg">&#39;model&#39;</span><span class="ansi-blue-fg">,</span> use_cuda <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">False</span><span class="ansi-blue-fg">)</span> <span class="ansi-red-fg"># использование CPU</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/simpletransformers/classification/classification_model.py</span> in <span class="ansi-cyan-fg">__init__</span><span class="ansi-blue-fg">(self, model_type, model_name, tokenizer_type, tokenizer_name, num_labels, weight, args, use_cuda, cuda_device, onnx_execution_provider, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    342</span>             self<span class="ansi-blue-fg">.</span>num_labels <span class="ansi-blue-fg">=</span> num_labels
# <span class="ansi-green-intense-fg ansi-bold">    343</span>         <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">--&gt; 344</span><span class="ansi-red-fg">             </span>self<span class="ansi-blue-fg">.</span>config <span class="ansi-blue-fg">=</span> config_class<span class="ansi-blue-fg">.</span>from_pretrained<span class="ansi-blue-fg">(</span>model_name<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>self<span class="ansi-blue-fg">.</span>args<span class="ansi-blue-fg">.</span>config<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    345</span>             self<span class="ansi-blue-fg">.</span>num_labels <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>config<span class="ansi-blue-fg">.</span>num_labels
# <span class="ansi-green-intense-fg ansi-bold">    346</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.8/site-packages/transformers/configuration_utils.py</span> in <span class="ansi-cyan-fg">from_pretrained</span><span class="ansi-blue-fg">(cls, pretrained_model_name_or_path, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    491</span>
# <span class="ansi-green-intense-fg ansi-bold">    492</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 493</span><span class="ansi-red-fg">         </span>config_dict<span class="ansi-blue-fg">,</span> kwargs <span class="ansi-blue-fg">=</span> cls<span class="ansi-blue-fg">.</span>get_config_dict<span class="ansi-blue-fg">(</span>pretrained_model_name_or_path<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    494</span>         <span class="ansi-green-fg">if</span> <span class="ansi-blue-fg">&#34;model_type&#34;</span> <span class="ansi-green-fg">in</span> config_dict <span class="ansi-green-fg">and</span> hasattr<span class="ansi-blue-fg">(</span>cls<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;model_type&#34;</span><span
